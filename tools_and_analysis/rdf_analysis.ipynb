# %%
# NOte book that read the RDF results produced with VMD's analysis tool

# %%
## Import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
## First lets see how the RDF looks like for  the AIMD SImulations

## T_160K

rdf_aimd_160_C_C = np.loadtxt('../aimd/T_160K/aimd_L_160K_rdf_C_C.dat')
rdf_aimd_160_C_H = np.loadtxt('../aimd/T_160K/aimd_L_160K_rdf_C_H.dat')
rdf_aimd_160_H_H = np.loadtxt('../aimd/T_160K/aimd_L_160K_rdf_H_H.dat')

# %%
#PLot the second column of the data file vs the first column
# change size of the figure
plt.figure(figsize=(9,6))
# plt.plot(rdf_aimd_160_C_C[:,0],rdf_aimd_160_C_C[:,1],label='C-C')
# plt.plot(rdf_aimd_160_C_H[:,0],rdf_aimd_160_C_H[:,1],label='C-H')
plt.title('RDF Butane AIMD 160K',fontsize=18,fontweight='bold')
plt.plot(rdf_aimd_160_H_H[:,0],rdf_aimd_160_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_aimd_160_C_C[:,0],rdf_aimd_160_C_C[:,1],label='C-C')
plt.plot(rdf_aimd_160_C_H[:,0],rdf_aimd_160_C_H[:,1],label='C-H')
plt.title('RDF Butane AIMD 160K',fontsize=18,fontweight='bold')
plt.plot(rdf_aimd_160_H_H[:,0],rdf_aimd_160_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
## Lets do the same for the 200K AIMD simulations

rdf_aimd_200_C_C = np.loadtxt('../aimd/T_200/aimd_L_200K_rdf_C_C.dat')
rdf_aimd_200_C_H = np.loadtxt('../aimd/T_200/aimd_L_200K_rdf_C_H.dat')
rdf_aimd_200_H_H = np.loadtxt('../aimd/T_200/aimd_L_200K_rdf_H_H.dat')


#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_aimd_200_C_C[:,0],rdf_aimd_200_C_C[:,1],label='C-C')
plt.plot(rdf_aimd_200_C_H[:,0],rdf_aimd_200_C_H[:,1],label='C-H')
plt.title('RDF Butane AIMD 200K',fontsize=18,fontweight='bold')
plt.plot(rdf_aimd_200_H_H[:,0],rdf_aimd_200_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
## Lets do the same for the 250K AIMD simulations

rdf_aimd_250_C_C = np.loadtxt('../aimd/T_250/aimd_L_250K_rdf_C_C.dat')
rdf_aimd_250_C_H = np.loadtxt('../aimd/T_250/aimd_L_250K_rdf_C_H.dat')
rdf_aimd_250_H_H = np.loadtxt('../aimd/T_250/aimd_L_250K_rdf_H_H.dat')


#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_aimd_250_C_C[:,0],rdf_aimd_250_C_C[:,1],label='C-C')
plt.plot(rdf_aimd_250_C_H[:,0],rdf_aimd_250_C_H[:,1],label='C-H')
plt.title('RDF Butane AIMD 250K',fontsize=18,fontweight='bold')
plt.plot(rdf_aimd_250_H_H[:,0],rdf_aimd_250_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
## Lets do the same for the 272K AIMD simulations

rdf_aimd_272_C_C = np.loadtxt('../aimd/T_272/aimd_L_272K_rdf_C_C.dat')
rdf_aimd_272_C_H = np.loadtxt('../aimd/T_272/aimd_L_272K_rdf_C_H.dat')
rdf_aimd_272_H_H = np.loadtxt('../aimd/T_272/aimd_L_272K_rdf_H_H.dat')



#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_aimd_272_C_C[:,0],rdf_aimd_272_C_C[:,1],label='C-C')
plt.plot(rdf_aimd_272_C_H[:,0],rdf_aimd_272_C_H[:,1],label='C-H')
plt.title('RDF Butane AIMD 272K',fontsize=18,fontweight='bold')
plt.plot(rdf_aimd_272_H_H[:,0],rdf_aimd_272_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# COmpare the RDF from types at different types

plt.figure(figsize=(9,6))
plt.plot(rdf_aimd_160_C_C[:,0],rdf_aimd_160_C_C[:,1],label='C-C 160K')
plt.plot(rdf_aimd_200_C_C[:,0],rdf_aimd_200_C_C[:,1],label='C-C 200K')
plt.plot(rdf_aimd_250_C_C[:,0],rdf_aimd_250_C_C[:,1],label='C-C 250K')
plt.plot(rdf_aimd_272_C_C[:,0],rdf_aimd_272_C_C[:,1],label='C-C 272K')
plt.title('RDF Butane AIMD C-C',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# DO the same for C-H

plt.figure(figsize=(9,6))
plt.plot(rdf_aimd_160_C_H[:,0],rdf_aimd_160_C_H[:,1],label='C-H 160K')
plt.plot(rdf_aimd_200_C_H[:,0],rdf_aimd_200_C_H[:,1],label='C-H 200K')
plt.plot(rdf_aimd_250_C_H[:,0],rdf_aimd_250_C_H[:,1],label='C-H 250K')
plt.plot(rdf_aimd_272_C_H[:,0],rdf_aimd_272_C_H[:,1],label='C-H 272K')
plt.title('RDF Butane AIMD C-H',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# DO the same for H-H

plt.figure(figsize=(9,6))
plt.plot(rdf_aimd_160_H_H[:,0],rdf_aimd_160_H_H[:,1],label='H-H 160K')
plt.plot(rdf_aimd_200_H_H[:,0],rdf_aimd_200_H_H[:,1],label='H-H 200K')
plt.plot(rdf_aimd_250_H_H[:,0],rdf_aimd_250_H_H[:,1],label='H-H 250K')
plt.plot(rdf_aimd_272_H_H[:,0],rdf_aimd_272_H_H[:,1],label='H-H 272K')
plt.title('RDF Butane AIMD H-H',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
## NOw lets read and plot the rdfs from clmd simulations 

rdf_clmd_160_C_C = np.loadtxt('../classical_MD/T_160K/nvt_production_160K_1ns/clmd_160K_rdf_C_C.dat')
rdf_clmd_160_C_H = np.loadtxt('../classical_MD/T_160K/nvt_production_160K_1ns/clmd_160K_rdf_C_H.dat')
rdf_clmd_160_H_H = np.loadtxt('../classical_MD/T_160K/nvt_production_160K_1ns/clmd_160K_rdf_H_H.dat')


#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_clmd_160_C_C[:,0],rdf_clmd_160_C_C[:,1],label='C-C')
plt.plot(rdf_clmd_160_C_H[:,0],rdf_clmd_160_C_H[:,1],label='C-H')
plt.title('RDF Butane CLMD 160K',fontsize=18,fontweight='bold')
plt.plot(rdf_clmd_160_H_H[:,0],rdf_clmd_160_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# Repeat with 200K

rdf_clmd_200_C_C = np.loadtxt('../classical_MD/T_200K/nvt_production_200K_1ns/clmd_200K_rdf_C_C.dat')
rdf_clmd_200_C_H = np.loadtxt('../classical_MD/T_200K/nvt_production_200K_1ns/clmd_200K_rdf_C_H.dat')
rdf_clmd_200_H_H = np.loadtxt('../classical_MD/T_200K/nvt_production_200K_1ns/clmd_200K_rdf_H_H.dat')


#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_clmd_200_C_C[:,0],rdf_clmd_200_C_C[:,1],label='C-C')
plt.plot(rdf_clmd_200_C_H[:,0],rdf_clmd_200_C_H[:,1],label='C-H')
plt.title('RDF Butane CLMD 200K',fontsize=18,fontweight='bold')
plt.plot(rdf_clmd_200_H_H[:,0],rdf_clmd_200_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
## Repeat with T = 250K

rdf_clmd_250_C_C = np.loadtxt('../classical_MD/T_250K/nvt_production_250K_1ns/clmd_250K_rdf_C_C.dat')
rdf_clmd_250_C_H = np.loadtxt('../classical_MD/T_250K/nvt_production_250K_1ns/clmd_250K_rdf_C_H.dat')
rdf_clmd_250_H_H = np.loadtxt('../classical_MD/T_250K/nvt_production_250K_1ns/clmd_250K_rdf_H_H.dat')

#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_clmd_250_C_C[:,0],rdf_clmd_250_C_C[:,1],label='C-C')
plt.plot(rdf_clmd_250_C_H[:,0],rdf_clmd_250_C_H[:,1],label='C-H')
plt.title('RDF Butane CLMD 250K',fontsize=18,fontweight='bold')
plt.plot(rdf_clmd_250_H_H[:,0],rdf_clmd_250_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# Repeat for T = 272K 


rdf_clmd_272_C_C = np.loadtxt('../classical_MD/T_272K/nvt_production_272K_1ns/clmd_272K_rdf_C_C.dat')
rdf_clmd_272_C_H = np.loadtxt('../classical_MD/T_272K/nvt_production_272K_1ns/clmd_272K_rdf_C_H.dat')
rdf_clmd_272_H_H = np.loadtxt('../classical_MD/T_272K/nvt_production_272K_1ns/clmd_272K_rdf_H_H.dat')


#PLot the second column of the data file vs the first column
plt.figure(figsize=(9,6))
plt.plot(rdf_clmd_272_C_C[:,0],rdf_clmd_272_C_C[:,1],label='C-C')
plt.plot(rdf_clmd_272_C_H[:,0],rdf_clmd_272_C_H[:,1],label='C-H')
plt.title('RDF Butane CLMD 272K',fontsize=18,fontweight='bold')
plt.plot(rdf_clmd_272_H_H[:,0],rdf_clmd_272_H_H[:,1],label='H-H')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# Compare the RDFs of the classical MD simulations at different temperatures

plt.figure(figsize=(9,6))
plt.plot(rdf_clmd_160_C_C[:,0],rdf_clmd_160_C_C[:,1],label='160K C-C')
plt.plot(rdf_clmd_200_C_C[:,0],rdf_clmd_200_C_C[:,1],label='200K C-C')
plt.plot(rdf_clmd_250_C_C[:,0],rdf_clmd_250_C_C[:,1],label='250K C-C')
plt.plot(rdf_clmd_272_C_C[:,0],rdf_clmd_272_C_C[:,1],label='272K C-C')
plt.title('RDF Butane CLMD C-C',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# Repeat for C-H

plt.figure(figsize=(9,6))
plt.plot(rdf_clmd_160_C_H[:,0],rdf_clmd_160_C_H[:,1],label='160K C-H')
plt.plot(rdf_clmd_200_C_H[:,0],rdf_clmd_200_C_H[:,1],label='200K C-H')
plt.plot(rdf_clmd_250_C_H[:,0],rdf_clmd_250_C_H[:,1],label='250K C-H')
plt.plot(rdf_clmd_272_C_H[:,0],rdf_clmd_272_C_H[:,1],label='272K C-H')
plt.title('RDF Butane CLMD C-H',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# Repeat for H-H

plt.figure(figsize=(9,6))
plt.plot(rdf_clmd_160_H_H[:,0],rdf_clmd_160_H_H[:,1],label='160K H-H')
plt.plot(rdf_clmd_200_H_H[:,0],rdf_clmd_200_H_H[:,1],label='200K H-H')
plt.plot(rdf_clmd_250_H_H[:,0],rdf_clmd_250_H_H[:,1],label='250K H-H')
plt.plot(rdf_clmd_272_H_H[:,0],rdf_clmd_272_H_H[:,1],label='272K H-H')
plt.title('RDF Butane CLMD H-H',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# Compare rdfs of the classical MD simulations and AIMD simulations at all temperatures for C-C

plt.figure(figsize=(9,6))

# plt.plot(rdf_clmd_160_C_C[:,0],rdf_clmd_160_C_C[:,1],label='CLMD 160K C-C')
# plt.plot(rdf_aimd_160_C_C[:,0],rdf_aimd_160_C_C[:,1],label='AIMD 160K C-C',linestyle='--')

# plt.plot(rdf_clmd_200_C_C[:,0],rdf_clmd_200_C_C[:,1],label='CLMD 200K C-C')
# plt.plot(rdf_aimd_200_C_C[:,0],rdf_aimd_200_C_C[:,1],label='AIMD 200K C-C',linestyle='--')

# plt.plot(rdf_clmd_250_C_C[:,0],rdf_clmd_250_C_C[:,1],label='CLMD 250K C-C')
# plt.plot(rdf_aimd_250_C_C[:,0],rdf_aimd_250_C_C[:,1],label='AIMD 250K C-C',linestyle='--')

plt.plot(rdf_clmd_272_C_C[:,0],rdf_clmd_272_C_C[:,1],label='CLMD 272K C-C')
plt.plot(rdf_aimd_272_C_C[:,0],rdf_aimd_272_C_C[:,1],label='AIMD 272K C-C',linestyle='--')



plt.title('RDF Butane CLMD vs AIMD C-C',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
## Repeat for C-H

plt.figure(figsize=(9,6))

plt.plot(rdf_clmd_160_C_H[:,0],rdf_clmd_160_C_H[:,1],label='CLMD 160K C-H')
plt.plot(rdf_aimd_160_C_H[:,0],rdf_aimd_160_C_H[:,1],label='AIMD 160K C-H',linestyle='--')

plt.plot(rdf_clmd_200_C_H[:,0],rdf_clmd_200_C_H[:,1],label='CLMD 200K C-H')
plt.plot(rdf_aimd_200_C_H[:,0],rdf_aimd_200_C_H[:,1],label='AIMD 200K C-H',linestyle='--')

plt.plot(rdf_clmd_250_C_H[:,0],rdf_clmd_250_C_H[:,1],label='CLMD 250K C-H')
plt.plot(rdf_aimd_250_C_H[:,0],rdf_aimd_250_C_H[:,1],label='AIMD 250K C-H',linestyle='--')

plt.plot(rdf_clmd_272_C_H[:,0],rdf_clmd_272_C_H[:,1],label='CLMD 272K C-H')
plt.plot(rdf_aimd_272_C_H[:,0],rdf_aimd_272_C_H[:,1],label='AIMD 272K C-H',linestyle='--')


plt.title('RDF Butane CLMD vs AIMD C-H',fontsize=18,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=12,fontweight='bold')
plt.ylabel('g(r)',fontsize=12,fontweight='bold')
plt.legend(fontsize=12)
plt.show()

# %%
# Repeat for H-H

plt.figure(figsize=(10,8),facecolor='white')

# plt.plot(rdf_clmd_160_H_H[:,0],rdf_clmd_160_H_H[:,1],label='CLMD 160K H-H')
# plt.plot(rdf_aimd_160_H_H[:,0],rdf_aimd_160_H_H[:,1],label='AIMD 160K H-H',linestyle='--')

# plt.plot(rdf_clmd_200_H_H[:,0],rdf_clmd_200_H_H[:,1],label='CLMD 200K H-H')
# plt.plot(rdf_aimd_200_H_H[:,0],rdf_aimd_200_H_H[:,1],label='AIMD 200K H-H',linestyle='--')

# plt.plot(rdf_clmd_250_H_H[:,0],rdf_clmd_250_H_H[:,1],label='CLMD 250K H-H')
# plt.plot(rdf_aimd_250_H_H[:,0],rdf_aimd_250_H_H[:,1],label='AIMD 250K H-H',linestyle='--')

plt.plot(rdf_clmd_272_H_H[:,0],rdf_clmd_272_H_H[:,1],label='CLMD')
plt.plot(rdf_aimd_272_H_H[:,0],rdf_aimd_272_H_H[:,1],label='AIMD',linestyle='--')


plt.title('RDF Butane CLMD vs AIMD H-H',fontsize=20,fontweight='bold')
plt.xlabel('r (Angstrom)',fontsize=18,fontweight='bold')
plt.ylabel('g(r)',fontsize=18,fontweight='bold')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Set x limit from 0 to 7
plt.xlim(0,7)
plt.legend(fontsize=16)
plt.show()
